# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
'condição inicial:'
# p = tal

def magnetic_field():
    B = 1e-10
    return np.array([0,0,B])
    
def velocity_eq(t,p):
    q = -1.602177e-19
    m =  9.109384e-31
    B = magnetic_field()
    #print(q/m * np.cross(p, B))
    
    return q/m * np.cross(p, B)
    

def rk_4(t, h, p, f):
    'h é o passo'
    'p é a coordenada espacial generalizada'
    'f é a função que representa o segundo membro da equação diferencial'
    
    k1 = f(t,p)
    k2 = f(t+h/2, p + h*k1/2)
    k3 = f(t+h/2, p + h*k2/2)
    k4 = f(t+h, p + k3*h)
    
    
    p += h/6 * (k1 + 2*k2 + 2*k3 + k4)
    t += h
    
    return p
    
    
p = np.array([1,0,0])
t = 0

P = np.zeros([10,3])
for i in range(len(P)):
    P[i] = rk_4(t,0.1,p,velocity_eq(t,p))

print(P)


X[:] = P[:,0]

Y[:] = P[:,1]

Z[:] = P[:,2]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X, Y, Z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-116aeefeaa06> in <module>()
#      37 P = np.zeros([10,3])
#      38 for i in range(len(P)):
# ---> 39     P[i] = rk_4(t,0.1,p,velocity_eq(t,p))
#      40
#      41 print(P)
#
# <ipython-input-32-116aeefeaa06> in rk_4(t, h, p, f)
#      20     'f é a função que representa o segundo membro da equação diferencial'
#      21
# ---> 22     k1 = f(t,p)
#      23     k2 = f(t+h/2, p + h*k1/2)
#      24     k3 = f(t+h/2, p + h*k2/2)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
'condição inicial:'
# p = tal

def magnetic_field():
    B = 1e-10
    return np.array([0,0,B])
    
def velocity_eq(t,p):
    return np.array([1,2,3])
    

def rk_4(t,h, p, f):
    'h é o passo'
    'p é a coordenada espacial generalizada'
    'f é a função que representa o segundo membro da equação diferencial'
    
    k1 = f(t,p)
    k2 = f(t+h/2, p + h*k1/2)
    k3 = f(t+h/2, p + h*k2/2)
    k4 = f(t+h, p + k3*h)
    
    
    p += h/6 * (k1 + 2*k2 + 2*k3 + k4)
    t += h
    
    return p
    
    
p = np.array([1,0,0])
t = 0

P = np.zeros([10,3])
P = rk_4(t,0.1,p,velocity_eq(t,np.array([ -0.        ,  17.58820355  ,-0.        ])))


X[:] = P[:,0]

Y[:] = P[:,1]

Z[:] = P[:,2]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X, Y, Z)
